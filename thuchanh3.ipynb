# %%
#1
#cách 1
a=int(input("Nhập số nguyên mong muốn: "))
tuyetdoi=abs(a)
dao=0
while tuyetdoi>0 :
    dao=dao*10+tuyetdoi%10
    tuyetdoi//=10
if a<0:
    dao=-dao
print(dao)
#cách 2
a=int(input("Nhập số nguyên mong muốn: "))
b=str(abs(a))[::-1]
if a>=0:
    print(b)
else:
    c=int(b)
    c*=-1
    print(c)

# %%
# bai2
a = int(input("Nhập số a: "))
b = int(input("Nhập số b: "))
a = a ^ b
b = a ^ b
a = a ^ b
print(a,b)
# Out:
# Nhập số a: 1
# Nhập số b: 2
# 2 1

# %%
#bai3
n = int(input("Nhập một số nguyên dương: "))
if n > 0 :
    print((n & (n - 1)) == 0)
else:
    print(False)

# %%
#bai4
a=int(input())
b=int(input())
print(int(a/b))

# %%
#bai5
a=int(input())
b=int(input())
print(int(a/b)+1)

# %%
#bai6
a=int(input())
if a%2==0:
    print("Even")
else:
    print("Odd")

# %%
#bai7
a=int(input())
b=int(input())
if a<0 and b<0 :
    print("Yes")
else:
    print("No")

# %%
#bai8
a=str(input())
b=str(input())
print(len(a)>len(b))

# %%
#bai9
a=int(input())
b=int(input())
c=int(input())
if a+b>c and a+c>b and b+c>a:
    print("Yes")
else:
    print("No")

# %%
#bai10
a = int(input())
b = int(input())
c = int(input())
d = int(input())

lonnhat = max(a, b, c, d)
print(lonnhat)

# %%
#bai11
a=int(input())
b=int(input())
c=int(input())
if a+b>c and a+c>b and b+c>a:
    if a==b==c:
        print("Tam giác đều")
    elif a==b or b==c or a==c:
        print("Tam giác cân")
    else:
        print("Tam giác thường")
else:
    print("Không phải tam giác")

# %%
#bai12
a=int(input())
if a%400==0:
    print("Yes")
else:
    print("No")

# %%
#bai13
a=int(input())
if a<=50:
    tien=a*1500
elif a<=100:
    tien=50*1500+(a-50)*2000
else:
    tien=50*1500+50*2000+(a-100)*3000
print(tien)

# %%
#bai14
a=int(input())
b=int(input())
if a!=0:
    print(-b/a)
elif a==0 and b==0:
    print("Vô số nghiệm")
else:
    print("Vô nghiệm")

# %%
#bai15
diem = float(input())
if diem >= 8.0:
    hoc_luc = "Giỏi"
elif diem >= 6.5:
    hoc_luc = "Khá"
elif diem >= 5.0:
    hoc_luc = "Trung bình"
else:
    hoc_luc = "Yếu"
print(hoc_luc)

# %%
#bai16
a = float(input())
import math
print(math.ceil(a))
print(math.floor(a))
print(round(a))

# %%
#bai17
a=int(input())
b=int(input())
c=int(input())
if a+b>c and a+c>b and b+c>a:
    if a==b==c:
        print("Tam giác đều")
    elif a==b or b==c or a==c:
        print("Tam giác cân")
    else:
        print("Tam giác thường")
else:
    print("Không phải tam giác")
